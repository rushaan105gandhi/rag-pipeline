# %%
# !pip install kaggle

# %%
from kaggle_secrets import UserSecretsClient
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-74bed3538e35> in <cell line: 1>()
# ----> 1 from kaggle_secrets import UserSecretsClient
#
# ModuleNotFoundError: No module named 'kaggle_secrets'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install -r kaggle_secrets
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'kaggle_secrets'
