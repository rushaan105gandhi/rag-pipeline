# %%
# !pip install keras-nlp
#upload kaggle.json
# !mv kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets list
# Out:
# ...
# ref                                                title                                      size  lastUpdated          downloadCount  voteCount  usabilityRating
# -------------------------------------------------  ----------------------------------------  -----  -------------------  -------------  ---------  ---------------
# syedanwarafridi/vehicle-sales-data                 Vehicle Sales Data                         19MB  2024-02-21 20:16:17          17012        299  1.0
# sudarshan24byte/online-food-dataset                Online Food Dataset                         3KB  2024-03-02 18:50:30           6647        115  0.9411765
# arnavvvvv/spotify-music                            Top Spotify Songs                          47KB  2024-03-06 05:20:29           5190         70  1.0
# bhavikjikadara/student-study-performance           Student Study Performance                   9KB  2024-03-07 06:14:09           4097         72  1.0
# ...

# %%
import keras
import keras_nlp
import numpy as np

# %%
# !pip install keras-nlp

# %%
gemma_lm = keras_nlp.models.GemmaCausalLM.from_preset("gemma_instruct_2b_en")
gemma_lm.generate("Keras is a", max_length=30)
# Out:
# Attaching 'config.json' from model 'keras/gemma/keras/gemma_instruct_2b_en/2' to your Colab notebook...
# Attaching 'config.json' from model 'keras/gemma/keras/gemma_instruct_2b_en/2' to your Colab notebook...
# Attaching 'model.weights.h5' from model 'keras/gemma/keras/gemma_instruct_2b_en/2' to your Colab notebook...
# Attaching 'tokenizer.json' from model 'keras/gemma/keras/gemma_instruct_2b_en/2' to your Colab notebook...
# Attaching 'assets/tokenizer/vocabulary.spm' from model 'keras/gemma/keras/gemma_instruct_2b_en/2' to your Colab notebook...
# 'Keras is a deep learning library for Python that provides a wide range of tools and functionalities for building, training, and evaluating deep learning models.'

# %%
gemma_lm.generate("full form of dbms", max_length=100)
# Out:
# "full form of dbms stands for?\n\n**Database Management System**\n\nSure, here's the full form of DBMS:\n\n**Database Management System**\n\nA DBMS is a software system that provides a comprehensive set of features for managing a database. A DBMS allows users to create, read, update, and delete data from a database in a secure and efficient manner.\n\nHere are some key features of a DBMS:\n\n* **Data definition language (DDL):** DDL is"

# %%
gemma_lm.summary()
# Out:
# Preprocessor: "gemma_causal_lm_preprocessor"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Tokenizer (type)                                   ┃                                             Vocab # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ gemma_tokenizer (GemmaTokenizer)                   │                                             256,000 │
# └────────────────────────────────────────────────────┴─────────────────────────────────────────────────────┘
# Model: "gemma_causal_lm"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# ...

# %%
gemma_lm.compile(sampler="top_k")
gemma_lm.generate("list acid properties in dbms", max_length=64)
# Out:
# "list acid properties in dbms\n\nSure, here's a list of acid properties in DBMS:\n\n1. **NotNull** - A constraint that ensures a field cannot be null.\n\n\n2. **Primary Key** - A constraint that specifies a field as the primary key of a table. \n\n\n3."

# %%
gemma_lm.generate("list acid properties in dbms", max_length=1000)
# Out:
# "list acid properties in dbms\n\nSure, here's a list of acid properties in DBMS:\n\n**1. ACID Properties:**\n\n- **Atomicity:** A transaction is treated as a single, indivisible unit of work. Either all of the operations in the transaction are completed successfully, or none of them are.\n- **Consistency:** Before a transaction starts, it must ensure that the data it will write to the database is consistent. This means that the data must meet the requirements of the data integrity constraints that are defined for the tables involved in the transaction.\n- **Isolation:** Transactions are isolated from each other, meaning that one cannot modify data that is being modified by another transaction. This ensures that each transaction sees a consistent view of the database.\n- **Durability:** Once a transaction has been committed, its changes are persisted to the database's storage medium. Data is durable until the transaction is rolled back or until the database is closed.\n\n**2. Other AC
# ...
